# %%
import matplotlib.pyplot as plt

# %%
x0=3
y0=3
x1=235
y1=100

# %%
x=0
y=0
m=(y1-y0)/(x1-x0)
x_list=[]
y_list=[]
while x<=x1:
    x_list.append(round(x))
    y_list.append(round(y))
    x+=1
    y=y+m
plt.scatter(x_list,y_list)
